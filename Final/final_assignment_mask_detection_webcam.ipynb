# %% [markdown]
# <a href="https://colab.research.google.com/github/nafisa-maliyat/cvpr/blob/main/Final/final_assignment_mask_detection_webcam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import tensorflow as tf

# %%
# Load the trained model
model = tf.keras.models.load_model('H:\Miniconda\cvpr_4234-master\Mask\mask_detector.model')

# Define the labels
labels = ['Mask', 'No Mask']

# Initialize the video stream
video = cv2.VideoCapture(0)

# %%
# Loop over the frames from the video stream
while True:
    # Read the next frame from qthe video stream
    ret, frame = video.read()

    # Preprocess the frame
    resized = cv2.resize(frame, (224, 224))
    normalized = resized / 255.0
    input_data = np.expand_dims(normalized, axis=0)

    # Make a prediction using the model
    output_data = model.predict(input_data)[0]
    prediction = np.argmax(output_data)
    label = labels[prediction]
    confidence = output_data[prediction] * 100

    # Draw the label and confidence on the frame
    text = f"{label} ({confidence:.1f}%)"
    color = (0, 0, 255) if prediction == 0 else (0, 255, 0)
    cv2.putText(frame, text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, color, 2)

    # Show the frame
    cv2.imshow('Mask Detector', frame)

    # Exit the loop if the user presses the 'q' key
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the video stream and close the window
video.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 25ms/step
